# %%
import numpy as np

def calculate_lateral_error1(A, direction_vector_A, B):
    # 计算 A 点的前进方向向量的单位向量
    unit_vector_A = direction_vector_A / np.linalg.norm(direction_vector_A)
    
    # 计算 B 点与 A 点的连线向量
    vector_AB = B - A
    
    # 计算连线向量 V 在单位向量 U 上的投影长度
    projection_length = np.dot(unit_vector_A, vector_AB)
    
    # 计算横向误差
    lateral_error = np.linalg.norm(vector_AB - projection_length * unit_vector_A)
    
    return lateral_error


def calculate_lateral_error(waypoint, vehicle_loc):
    # 计算 A 点的前进方向向量的单位向量
    
    unit_vector_A = direction_vector_A / np.linalg.norm(direction_vector_A)
    
    # 计算 B 点与 A 点的连线向量
    vector_AB = B - A
    
    # 计算连线向量 V 在单位向量 U 上的投影长度
    projection_length = np.dot(unit_vector_A, vector_AB)
    
    # 计算横向误差
    lateral_error = np.linalg.norm(vector_AB - projection_length * unit_vector_A)
    
    return lateral_error

# 测试示例
A = np.array([3,0])
direction_vector_A = np.array([1,1])
B = np.array([0,0])

lateral_error = calculate_lateral_error(A, direction_vector_A, B)
print("横向误差：", lateral_error)
# Out:
# 横向误差： 2.1213203435596424
